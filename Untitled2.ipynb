# %%
import csv
import re

temp=[]
langages = ['php', 'python' , 'java','android','c++','asp.net','c' ,'xml','javascript','.net','c#',
           'oop','sql','nhibernate','asp.net-mvc','ruby','ruby-on-rails','asp.net-ajax','jquery','soap',
            'soap','regex','mysql','html','css','php','ios','windows','linux','hibernate','xhml','cocoa',
            'tomcat','oracle','ajax','sharepoint'] # add all langages to this list

with open('Edited Dataset_Copy.csv') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
        if line_count == 0:
            line_count += 1
        else:
            line_count += 1

            tags = []

            list = re.split('>|<', row[1])

            for seg in list:
                if seg != "":
                    tags.append(seg)  # only store tag attributes
            

            unmatch = 0

            for given_tag in tags:
                bag = []
                for lang in langages:
                    if given_tag == lang:
                        bag.append('Y')
                        temp.append(row[0]+" : "+given_tag)
                        break  # responsible for stop comparing after at least one matched tag in langages list
                    else:
                        bag.append('N')

                count = 0
                for item in bag:
                    if item == 'N':
                        count += 1
                # print(count)
                if count != len(langages):
                    break  # responsible for storing at least one matched tag in temp array and go to analyse next row
                else:
                    unmatch += 1

            if unmatch == len(tags):
                temp.append(row[0]+" : null") # inserting null value for indicating no any match tags

print(temp)
# Out:
# ['1935115 : android', '1887758 : android', '1266145 : null', '1197888 : asp.net', '963535 : java', '654565 : xml', '1142067 : javascript', '1611471 : sharepoint', '1716113 : sharepoint', '454113 : c#', '463419 : .net', '492936 : c#', '617924 : null', '614107 : null', '1855671 : sql', '1451072 : asp.net', '554689 : asp.net', '826785 : nhibernate', '806097 : nhibernate', '774089 : null', '704431 : null', '459427 : null', '587179 : asp.net-mvc', '537408 : c#', '461983 : null', '736204 : .net', '1562733 : null', '734478 : null', '1009963 : c#', '730220 : nhibernate', '1578612 : ruby', '1016309 : null', '1017934 : ruby-on-rails', '944944 : .net', '958422 : null', '1597195 : null', '617105 : asp.net', '1095268 : null', '1450243 : null', '463800 : javascript', '727859 : asp.net-ajax', '990799 : null', '647112 : android', '429758 : c#', '849682 : null', '572138 : asp.net', '758264 : asp.net', '656866 : null', '425424 : c#', '821075 : .net', '475081 : c++', '808059 : soap', '927441 : javascript', '1843911 : android', '998721 : regex', '1134223 : .net', '548043 : null', '1233515 : null', '833292 : java', '1406931 : java', '1764654 : mysql', '1064520 : python', '1375078 : null', '458289 : null', '484143 : asp.net', '1233939 : asp.net', '1829187 : c', '813618 : javascript', '897907 : null', '962361 : python', '1278258 : asp.net', '1460390 :